# %%
import pandahouse as ph

# %%
connection = {
            'host': '******',
            'database': '******',
            'user': '******',
            'password': '******'
        }

q = """
SELECT 
    *
FROM 
    {db}.a_belinskii_metric
ORDER BY
    event_date DESC
LIMIT 
    100
"""

# %%
data = ph.read_clickhouse(q, connection=connection)
data
# Out:
#    event_date dimension dimension_value   views  likes  messages_received  \
# 0  2026-03-01        os             iOS  175975  36709                540
# 1  2026-03-01        os         Android  332016  69202                614
# 2  2026-03-01    gender               1  279777  58318                715
# 3  2026-03-01    gender               0  228214  47593                439
# 4  2026-03-01       age              83      17      1                  0
# ..        ...       ...             ...     ...    ...                ...
# 95 2026-02-28       age              54    2019    432                  0
# 96 2026-02-28       age              53    1930    407                  0
# 97 2026-02-28       age              52    2701    529                  0
# 98 2026-02-28       age              51    3491    702                  0
# 99 2026-02-28       age              50    3819    829                  0
#
#     messages_sent  users_received  users_sent
# ...
